# %% [markdown]
# # DS-SF-36 | 06 | $k$-Nearest Neighbors | Codealong | Starter Code

# %%
import os

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

from sklearn import preprocessing, neighbors, model_selection

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-06-iris.csv'))

# %%
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth    Species
# 0            5.1         3.5          1.4         0.2     Setosa
# 1            4.9         3.0          1.4         0.2     Setosa
# 2            4.7         3.2          1.3         0.2     Setosa
# 3            4.6         3.1          1.5         0.2     Setosa
# 4            5.0         3.6          1.4         0.2     Setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  Virginica
# 146          6.3         2.5          5.0         1.9  Virginica
# 147          6.5         3.0          5.2         2.0  Virginica
# 148          6.2         3.4          5.4         2.3  Virginica
# 149          5.9         3.0          5.1         1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Part A | Activity | Iris Dataset | Exploratory Data Analysis

# %%
df.plot.scatter(x = 'PetalLength', y = 'PetalWidth', s = 100, figsize = (10, 10), c = color)

# %%
pd.tools.plotting.scatter_matrix(
    df[['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']] ,
   # diagonal = 'kde', # 
    s = 100, c = color, figsize = (10,10)
)
# Out:
# C:\Users\einst_000\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   after removing the cwd from sys.path.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F420C84588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F420A55438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F420A69128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F420B25E48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F420ABEA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F420ABEC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F420E38C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F420EB5A20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F420F1C470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F420F58908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F420FE1F60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F420FF9588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F4210ADF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F421112748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F42117AF60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4211E4320>]], dtype=object)

# %%
pd.tools.plotting.scatter_matrix(df[['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']],diagonal = 'kde', s =100, c= color, figsize = (10,10))
# Out:
# C:\Users\einst_000\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F41FCADE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F420405A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F420183E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F42023DD68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F42029F710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F42029F748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4203702E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4205ED080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F41FBF87B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F42064BE80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4206A90F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4206E0198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F4207734A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4207854E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F4208406A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F420891F28>]], dtype=object)

# %% [markdown]
# ## Part B | Activity | Hand-Coded Classifier

# %%
c = df.Species

# %%
def my_first_classifier(row):
    if row.PetalLength >5:
        return "Virginica"
    elif row.PetalLength > 2.5:
        return 'Versicolor'
    else:
        return "Setosa"

# %%
c_hat = df.apply(my_first_classifier, axis = 1)

c_hat
# Out:
# 0          Setosa
# 1          Setosa
# 2          Setosa
# 3          Setosa
# 4          Setosa
#           ...
# 145     Virginica
# 146    Versicolor
# 147     Virginica
# 148     Virginica
# 149     Virginica
# Length: 150, dtype: object

# %%
(c_hat != c).sum()
# Out:
# 10

# %%
pd.crosstab(c_hat, c, rownames = ['Hypothesized Class'], colnames = ['True Class'])
# Out:
# True Class          Setosa  Versicolor  Virginica
# Hypothesized Class
# Setosa                  50           0          0
# Versicolor               0          49          9
# Virginica                0           1         41

# %% [markdown]
# ## Part C | Classification Metrics

# %% [markdown]
# ### Accuracy

# %%
(c_hat == c).mean()
# Out:
# 0.93333333333333335

# %% [markdown]
# ### Misclassification rate

# %%
(c_hat != c).mean()
# Out:
# 0.066666666666666666

# %% [markdown]
# ## Part D | $k$-Nearest Neighbors ($k$-NN)

# %% [markdown]
# ### Feature matrix and response vector

# %% [markdown]
# - (http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html)

# %%
columns_X = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']
X = df[columns_X]

scaler = preprocessing.MinMaxScaler().fit(X)

X = scaler.transform(X)

# %%
# TODO

# %%
c = df.Species

# %%
c

# %% [markdown]
# ### $k$-Nearest Neighbors

# %% [markdown]
# - (http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)

# %%
model = neighbors.KNeighborsClassifier(n_neighbors = 1).\
    fit(X, c)

# %% [markdown]
# You can measure the precision of your prediction with `.score()`

# %%
model.score(X, c)

# %%
c_hat = model.predict(X)

# %%
(c_hat == c).mean()

# %%
pd.crosstab(c_hat, c, rownames = ['Hypothesized Class'], colnames = ['True Class'])

# %% [markdown]
# ### Train/test sets

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sample.html)

# %% [markdown]
# 50% of the dataset to train the model; the rest to test the model

# %%
train_df = df.sample(frac = .5, random_state = 0).sort_index()

# %%
train_df

# %%
test_df = df.drop(train_df.index)

# %% [markdown]
# ### Feature matrix `train_X` and response vector `train_c`

# %%
train_X = train_df[columns_X]

scaler = preprocessing.MinMaxScaler().fit(train_X)
train_X = scaler.transform(train_X)

train_c = train_df.Species

# %% [markdown]
# ### Feature matrix `test_X` and response vector `test_c`

# %% [markdown]
# - (http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)
# - (http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html)

# %%
# TODO

# %%
k_cv = 5 # 5-fold CV
k_nn = range(1, train_df.shape[0] * (k_cv - 1) / k_cv) # k-NN

gs = model_selection.GridSearchCV(
    estimator = neighbors.KNeighborsClassifier(),
    param_grid = {'n_neighbors': k_nn, 'weights': ['uniform', 'distance']},
    cv = model_selection.KFold(n_splits = k_cv, shuffle = True, random_state = 0)
)

gs.fit(train_X, train_c)

# %%
gs.cv_results_

# %%
gs.cv_results_.keys()

# %%
gs.best_score_

# %%
gs.best_params_

# %%
gs.best_estimator_

# %%
gs.score(train_X, train_c)

# %%
gs.score(test_X, test_c)

# %% [markdown]
# ## Final model

# %%
# TODO
