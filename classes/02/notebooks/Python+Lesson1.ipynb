# %% [markdown]
# # <b>Python Refresher Lesson</b>

# %% [markdown]
# ## Objective

# %% [markdown]
# - Main goal today is to make sure everyone in the class is up to speed on the Python topics we cover in class.
# - Topics we'll be covering tonight, as determined by my survey, are:
#     - Control Flow (If, Elif, Else Statements)
#     - Loops (For and While) and Lists
#     - Dictionaries
#     - Functions
#     - Importing and using packages
# - Last 45mins - 1 hour will be devoted to exercises.

# %% [markdown]
# ### <b>Control Flow</b>

# %% [markdown]
# #### If Statements

# %% [markdown]
# • Used to execute commands when defined
# conditions are met
#
# • Contains a conditional statement that has a
# True/False value
#
# • If statement is True then a series of
# commands will be executed
#
# • If the statement is False then commands are
# skipped

# %%
x = 20
# x == 20 is a boolean, its value is True
if x == 20:
    print ("Hello")
    
# x > 30 is a False boolean
if x >30:
    print ("How are you")
# Out:
# Hello

# %%
from IPython.display import Image
Image(filename='if_statemen_img.png')

# %% [markdown]
# Some examples of conditional statements:

# %%
8 == 2**3
# Out:
# True

# %%
20 >= 40-23
# Out:
# True

# %%
10 != 10
# Out:
# False

# %% [markdown]
# Multiple Conditions

# %%
x = 30

# %%
#True and True = True
x > 20 and x <40
# Out:
# True

# %%
#True and False = False
x > 0 and x != 30
# Out:
# False

# %%
#True or False = True
x >= 25 or x<0
# Out:
# True

# %%
#False or False = False
x >40 or x <20
# Out:
# False

# %% [markdown]
# ### Else and Else if aka Elif

# %%
Image("else_elif.png")

# %%
x = 5
#Control flow with if and else
if x >0:
    print ("X is not negative")
else:
    print ("X is negative")
# Out:
# X is not negative

# %%
#Control flow with if, elif, and else
x= -5
if x > 0:
    print ("X is positive")
elif x < 0:
    print ("X is negative")
else:
    print ("X is zero")
# Out:
# X is negative

# %% [markdown]
# ### <b>Lists and Loops</b>

# %% [markdown]
# • Lists are ordered data containers
#
# • Lists are defined with square brackets [ ]
#
# • They can contain any type of objects
#
#     – Mix of data types (e.g., integer, string, float)
#     – Lists can even contain other lists
#
# • List are mutable (you can edit them)
#
# • Uses index to reference items in lists
#
# • Lists can be empty
#
# • Remember! Lists indices begin at zero. First item in a list is item number 0, not item number

# %%
#Examples of lists
sf = ["haight", "soma", "mission", "hayes", "nopa", "sunset"]
floaters = [20.3, 11.2, 23.9, 4.5, 9.2, 13.4]
boo = [True, True, False, True, False]
misc = ["jerry", True, 2, 99.32]

# %%
#Calls hayes
sf[3]
# Out:
# 'hayes'

# %%
#Calls first three values. Known as slicing.
sf[:3]
# Out:
# ['haight', 'soma', 'mission']

# %%
#Reassigning a value of a list
boo[0] = False
boo
# Out:
# [False, True, False, True, False]

# %%
# You can put lists in lists. Known as nested lists
nest = [[2,3,7], 9,[11,32,5,9]]
nest2 = [sf, floaters, boo]

# %%
#How do you access the 7 value in the nest list?
nest [0][2]
# Out:
# 7

# %%
#How do you access the nopa value in the nest2 list?
nest2[0][4]
# Out:
# 'nopa'

# %%
#Appending adds values to the end of a list
sf.append("richmond")
sf
# Out:
# ['haight', 'soma', 'mission', 'hayes', 'nopa', 'sunset', 'richmond']

# %%
nest.append([34, 48.2])
nest
# Out:
# [[2, 3, 7], 9, [11, 32, 5, 9], [34, 48.2]]

# %% [markdown]
# ### <b>For loops</b>
#
# - Executes an action "for" each value in an object. Known as "iteration."
#
# - Iterates through multiple values
#
# - Commonly used to process values in a list
#
# - Loop of code is executed for each item

# %%
Image("loops.png")

# %%
#Print each item in the sf list

for i in sf:
    print (i)
# Out:
# haight
# soma
# mission
# hayes
# nopa
# sunset
# richmond

# %%
#You can also iterate over a string

for i in sf[0]:
    print (i)
# Out:
# h
# a
# i
# g
# h
# t

# %% [markdown]
# Lets take list A and make a new list B, that is the squares of the values in A
#
# How do we go about doing that?

# %%
A = [3,5,8,9,2,3,5,7]

B = []

for i in A:
    B.append(i**2)
B
# Out:
# [9, 25, 64, 81, 4, 9, 25, 49]

# %% [markdown]
# Create a list of capitalized San Francisco neighborhoods

# %%
SF = []

for i in sf:
    capital = i.upper()
    SF.append(capital)
SF
# Out:
# ['HAIGHT', 'SOMA', 'MISSION', 'HAYES', 'NOPA', 'SUNSET', 'RICHMOND']

# %% [markdown]
# Find the maximum value in A

# %%
A
# Out:
# [3, 5, 8, 9, 2, 3, 5, 7]

# %%
mx = 0    #we can alson do     mx = A[0]

for i in A:
    if i > mx:
        mx = i
mx
# Out:
# 9

# %%
max(A)
# Out:
# 9

# %% [markdown]
# ### <b>List Comprehensions</b>
# - In addition to sequence operations and list methods, Python includes a more advanced operation called a list comprehension.
#
# - List comprehensions allow us to build out lists using a different notation. You can think of it as essentially a one line for loop built inside of brackets.

# %%
word = [i.upper() for i in "word"]
word
# Out:
# ['W', 'O', 'R', 'D']

# %%
# Square numbers in range and turn into list
lst = [x**2 for x in range(0,11)]
lst
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
#Add 1 to every number in a list using append and a for loop

c = [3,7,3,4,5,9,1,12]
c1 = []

for i in c:
    c1.append(i + 1)

# %%
#What is the list comprehension version of this?

c1 = [i + 1 for i in c]
c1
# Out:
# [4, 8, 4, 5, 6, 10, 2, 13]

# %%
#What is the list comprehension version of this script?

q = []

for i in c:
    if i != 3:
        q.append(i**2-5)
q
# Out:
# [44, 11, 20, 76, -4, 139]

# %%
q = [i**2-5 for i in c if i != 3]
q
# Out:
# [44, 11, 20, 76, -4, 139]

# %% [markdown]
# ### <b>While Loops</b>
#
# - The while statement in Python is one of most general ways to perform iteration.
#
# - A while statement will repeatedly execute a single statement or group of statements as long as the condition is true.
#
# - The reason it is called a 'loop' is because the code statements are looped through over and over again until the condition is met.
#
# - The general format of a while loop is:
#
#
#     while True condition:
#         code statement
#     else:
#         final code statement

# %%
x = 0

while x < 7:
    print ('x is currently: ',x)
    print (' x is still less than 7, adding 1 to x')
    x+=1
# Out:
# x is currently:  0
#  x is still less than 7, adding 1 to x
# x is currently:  1
#  x is still less than 7, adding 1 to x
# x is currently:  2
#  x is still less than 7, adding 1 to x
# x is currently:  3
#  x is still less than 7, adding 1 to x
# x is currently:  4
#  x is still less than 7, adding 1 to x
# x is currently:  5
#  x is still less than 7, adding 1 to x
# x is currently:  6
#  x is still less than 7, adding 1 to x

# %% [markdown]
# Notice how the while loop kept going until the condition turned from True to False

# %% [markdown]
# Lets introduce an If statement into the mix

# %%
x = 0

while x < 7:
    print ('x is currently: ',x)
    print (' x is still less than 7, adding 1 to x')
    x+=1
    if x ==3:
        print ('x==3')
    else:
        print ('continuing...')
        continue
# Out:
# x is currently:  0
#  x is still less than 7, adding 1 to x
# continuing...
# x is currently:  1
#  x is still less than 7, adding 1 to x
# continuing...
# x is currently:  2
#  x is still less than 7, adding 1 to x
# x==3
# x is currently:  3
#  x is still less than 7, adding 1 to x
# continuing...
# x is currently:  4
#  x is still less than 7, adding 1 to x
# continuing...
# x is currently:  5
#  x is still less than 7, adding 1 to x
# continuing...
# x is currently:  6
#  x is still less than 7, adding 1 to x
# continuing...

# %%
# # DO NOT RUN THIS CODE!!!! 
# while True:
#     print 'Infinite Loop!'

# %% [markdown]
# ### <b>Dictionaries</b>
# - Dictionaries are collections of key-value pairs
#
# - Dictionaries are indicated by curly braces { }
#
# - Values are looked up by key
#
# - Dictionaries are unordered
#
# - Think of it as an actual dictionary, where words are the keys and definitions are the values

# %%
d = {"bob":34,
    "angela": 23,
    "greg": 19,
    "pam": 47}

#Call d's keys
print (d.keys())

#Call d's values
print (d.values())
# Out:
# dict_keys(['bob', 'angela', 'greg', 'pam'])
# dict_values([34, 23, 19, 47])

# %%
#To access a value, pass its corresponding key through the dictionary
d["bob"]
# Out:
# 34

# %%
#Create a new value in the dictionary by assigning a new key to a new value

d["tommy"] =  55
d["cody"] = 14

d
# Out:
# {'angela': 23, 'bob': 34, 'cody': 14, 'greg': 19, 'pam': 47, 'tommy': 55}

# %%
#Its important to note that dictionaries are very flexible in the data types they can hold. For example:
my_dict = {'key1':123,'key2':[12,23,33],'key3':['item0','item1','item2']}

# %%
# Can call an index on that value
my_dict['key3'][0]
# Out:
# 'item0'

# %%
# Subtract 123 from the value
my_dict['key1'] = my_dict['key1'] - 123
my_dict
# Out:
# {'key1': 0, 'key2': [12, 23, 33], 'key3': ['item0', 'item1', 'item2']}

# %% [markdown]
# Nested dictionaries like nested lists, are dictionaries within dictionaries.

# %%
# Dictionary nested inside a dictionary nested in side a dictionary
di = {'key1':{'nestkey':{'subnestkey':'value'}}}

# %%
#How do I call "value"?
di["key1"]["nestkey"]["subnestkey"]
# Out:
# 'value'

# %% [markdown]
# Dictionaries can be iterated over like lists.

# %%
#Method 1. Iterate over the keys and then use key to call value
for key in d.keys():
    value = d[key]
    print (value)
# Out:
# 34
# 23
# 19
# 47
# 55
# 14

# %%
#Method 2. Use items method.
#What happens when you do d.items()
d.items()
# Out:
# dict_items([('bob', 34), ('angela', 23), ('greg', 19), ('pam', 47), ('tommy', 55), ('cody', 14)])

# %%
for k, v in d.items():
    print (k, "\t", v)
# Out:
# bob 	 34
# angela 	 23
# greg 	 19
# pam 	 47
# tommy 	 55
# cody 	 14

# %%
# find the max age person in this dictionary

max_age = 0
person = ""
for i in d.keys():
    v = d[i]
    if max_age < v:
            max_age =v
            person =i
person
# Out:
# 'tommy'

# %%
max_age = 0
person = ""
for k, v in d.items():
    if max_age < v:
        max_age = v
        person = k
person
# Out:
# 'tommy'

# %% [markdown]
# #### Exercise 1:
# Create dictionary where the keys are the unique values from list Y and the values are the counts of those values.
#
# Input:
#
# ['p', 'k', 'f', 'n', 'f', 'n', 'f', 'c', 'n', 'w', 'e', 'w', 'n', 'p', 'w', 'o', 'e', 'w',]
#
# Output:
#
# {'c': 1, 'e': 2, 'f': 3, 'k': 1, 'n': 4, 'o': 1, 'p': 2, 'w': 4}

# %%
a = {}
Y = ['p', 'k', 'f', 'n', 'f', 'n', 'f', 'c', 'n', 'w', 'e', 'w', 'n', 'p', 'w', 'o', 'e', 'w',]

for i in Y:
    if i in a:
        a[i] += 1
    else:
        a[i] = 1
a
# Out:
# {'c': 1, 'e': 2, 'f': 3, 'k': 1, 'n': 4, 'o': 1, 'p': 2, 'w': 4}

# %% [markdown]
# #### Exercise 2:
#
# There are two lists. Players list is the names of Warriors players and ppg list is their points per game averages.
#
# Create a dictionary where the keys are the players' names and the values are their corresponding ppg.
#
# This is the output:
#
# {'curry': 25.6, 'draymond': 13.8, 'iggy': 11.8, 'javale': 6.8, 'klay': 24.1}

# %%
players = ["curry", "draymond", "klay", "iggy", "javale"]
ppg = [25.6, 13.8, 24.1, 11.8, 6.8]

# %%
gsw = {}

for i in range(len(players)):
    player = players[i]
    points = ppg[i]
    gsw[player] = points
gsw
# Out:
# {'curry': 25.6, 'draymond': 13.8, 'iggy': 11.8, 'javale': 6.8, 'klay': 24.1}

# %%
for i in range(len(players)):
    
    gsw[players[i]] = ppg [i]
    
gsw
# Out:
# {'curry': 25.6, 'draymond': 13.8, 'iggy': 11.8, 'javale': 6.8, 'klay': 24.1}

# %% [markdown]
# ### <b>Functions</b>
# One of the core principles of any programming language is, "Don't Repeat Yourself". If you have an action that should occur many times, you can define that action once and then call that code whenever you need to carry out that action.
#
# It's very easy to repeat yourself in your code, which can lead to piles of messy code. Functions mean less work for us as programmers, and effective use of functions results in code that is less error-prone.

# %%
Image("funk.png")

# %% [markdown]
# ### What are Functions?
# - Functions are a set of actions that we group together, and give a name to. You have already used a number of natural Python functions, such as "print" and "len."
#
# - As we've learned earlier, Python's system for naming is quite literal. Functions at the basic level take in an input and return an output, just like a mathematical function

# %% [markdown]
# ### Defining a function
#
# - Give the keyword def, which tells Python that you are about to define a function.
# - Give your function a name. A variable name tells you what kind of value the variable contains; a function name should tell you what the function does. Use workable names.
# - Give names for each value the function needs in order to do its work. These are basically variable names, but they are only used in the function.
# - They can be different names than what you use in the rest of your program.
# - These are called the function's arguments.
# - Make sure the function definition line ends with a colon.
# - Inside the function, write whatever code you need to make the function do its work.

# %%
# Let's define a function.
def funk(argument):
    
    # Do whatever we want this function to do,

# Use function_name to call the function.
funk(value)

# %% [markdown]
# ### Using your function
#
# - To call your function, write its name followed by parentheses.
# - Inside the parentheses, give the values you want the function to work with.
# - These can be variables such as current_name and current_age, or they can be actual values such as 'eric' and 5.

# %%
def temp(c):
    f = c*1.8 + 32
    return f

print (temp(10))
print (temp(28))
# Out:
# 50.0
# 82.4

# %%
def circle_area(r):
    #Note: the "pi" variable only works within the scope of the function. 
    #If call "pi" outside function, Python will tell you the variable is undefined.
    pi = 3.141
    return pi*r**2

print (circle_area(5))

#Assign the area of a circle with radius 8.36 to variable ca
ca = circle_area(8.36)
print (ca)
# Out:
# 78.525
# 219.52323359999997

# %%
#Function with two arguments
def funk2(argument_1, argument_2):
    # Do whatever we want this function to do,
    #  using argument_1 and argument_2

# Use function_name to call the function.
funk2(value_1, value_2)

# %%
def perimeter(w, l):
    return 2*w + 2*l

#assign perimeter function with values 3 and 4 to variable p and print p
p = perimeter(3,4)
p
# Out:
# 14

# %%
#Function that takes in and returns a string
def emailer(first_name, last_name):
    #Functions returns the email format for a company.
    base = "@company.com"
    initial = first_name[0]
    return initial + last_name + base

emailer("Katy", "Perry")
# Out:
# 'KPerry@company.com'

# %% [markdown]
# Lets create functions that derives the mean and median values of a list

# %%
l = [23,45,19,33,44,61,91,53,10]

# %%
#Mean

def mean(lst):
    return sum(lst)/float(len(lst))

mean(l)
# Out:
# 42.111111111111114

# %%
def median(lst):
    l = sorted(lst)
    if len(l) % 2 == 1:
        index = len(l)/2
        med = l[index]
        return med
    else:
        index1 = len(l)/2
        index2 = len(l)/2 - 1
        value1 = l[index1]
        value2 = l[index2]
        return mean(value1, value2)/2.
     
median([2,3,9,6,7,8])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-192-dfb5efe3fdf9> in <module>()
#      12         return mean(value1, value2)/2.
#      13
# ---> 14 median([2,3,9,6,7,8])
#
# <ipython-input-192-dfb5efe3fdf9> in median(lst)
#       8         index1 = len(l)/2
#       9         index2 = len(l)/2 - 1
# ---> 10         value1 = l[index1]
#      11         value2 = l[index2]
#      12         return mean(value1, value2)/2.
#
# TypeError: list indices must be integers or slices, not float

# %% [markdown]
# #### Exercise 3
#
# Create a function that takes in a list of grades on a 0-100 scale and returns a list of their corresponding letter grade.
# For example: the function would turn [93,82,75,68] into ["A", "B", "C", "D"]

# %%
grades = [83, 78, 99, 82, 74, 68, 61, 85]

# %%
def letter_grade(grades):
    output = []
    for i in grades:
        if i >= 90:
            output.append("A")
        elif i >= 80 and i < 90:
            output.append("B")
        elif i >= 70 and i < 80:
            output.append("C")
        else:
            output.append("D")
    return output
letter_grade(grades)
# Out:
# ['B', 'C', 'A', 'B', 'C', 'D', 'D', 'B']

# %% [markdown]
# ### <b> Importing and Using Packages</b>

# %% [markdown]
# - Data analytics packages are what make python so powerful
#
# - Packages are just files of python code
#
# - Importing packages allow you to use the functions from these files
#
# - Most packages have online documentation and code examples

# %%
img("pack.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-96820842f588> in <module>()
# ----> 1 img("pack.png")
#
# NameError: name 'img' is not defined

# %%
Image("pack2.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-f76429d542bc> in <module>()
# ----> 1 Image("pack2.png")
#
# NameError: name 'Image' is not defined

# %%
#Plain import statement
import math

# %%
#Use a nickname
import datetime as dt
now = dt.datetime.now()
now
# Out:
# datetime.datetime(2017, 6, 26, 20, 48, 39, 986183)

# %%
#What happens when you run this code
print now.year, "\n"
print now.month, "\n"
print now.minute, "\n" 
print now.second, "\n"
# Out:
#   File "<ipython-input-138-a5d6d20167ed>", line 2
#     print now.year, "\n"
#             ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
#Import a subset of the package
from numpy import median

# %%
#Call median on list l

# %%
#Call dir(math). What does that do?

# %%
#Use the sin and pi methods on math to calculate the sin of pi

# %% [markdown]
# ## <b>Coding Best Practices</b>
# - Write a simple description of your functions in first line after defining function
#
# - Include descriptions of each input parameter and return value (e.g., name, description, data type)
#
# - Use intuitive variable names
#
# - Test early and often
#
# - print command is your best friend
#
# - Identify common mistakes and use as checklist for debugging
#
# - Use google and stackoverflow
#
# - Check documentation
#
# - Ask for help

# %% [markdown]
# ## <b>Further Resources</b>
#
# - Complete the free Codeacademy and DataQuest Python tutorials.
#
# - Have a look at the following Github repos:
#
#     - https://github.com/tdpetrou/Intro-Python-Programming
#
#     - https://github.com/jakevdp/WhirlwindTourOfPython
#
#     - https://github.com/ehmatthes/intro_programming
#
#
# - Good resource for IPython tricks and tips:
#     - http://nbviewer.jupyter.org/github/ipython/ipython/blob/4.0.x/examples/IPython%20Kernel/Index.ipynb
